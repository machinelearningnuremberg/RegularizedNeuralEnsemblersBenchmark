# %%
import SearchingOptimalEnsembles.metadatasets.tabrepo.metadataset as tabrepod

import numpy as np
import seaborn as sns

# %%
metadataset = tabrepod.TabRepoMetaDataset()
metadataset.set_state(metadataset.dataset_names[0])
X_obs = [i for i in range(len(metadataset.hp_candidates_ids))]
X_obs = np.random.choice(X_obs, 120)

# %%
predictions = metadataset.get_predictions([X_obs.tolist()])
subset = predictions.squeeze(0)[...,0]
sns.heatmap(subset,cmap='coolwarm')
# Out:
# <Axes: >

# %%
subset[:,0]
# Out:
# tensor([0.1537, 0.2308, 0.1713, 0.0357, 0.3212, 0.4106, 0.0386, 0.2553, 0.2050,
#         0.2640, 0.1653, 0.1726, 0.2109, 0.2265, 0.3100, 0.2389, 0.0738, 0.3523,
#         0.2123, 0.2640, 0.2723, 0.0885, 0.0711, 0.1608, 0.4237, 0.1711, 0.3536,
#         0.7202, 0.2597, 0.2669, 0.2441, 0.2103, 0.2114, 0.1935, 0.3468, 0.1610,
#         0.1292, 0.4422, 0.2103, 0.4013, 0.1805, 0.2219, 0.1807, 0.1187, 0.2498,
#         0.2793, 0.2774, 0.1995, 0.2515, 0.1976, 0.2814, 0.2321, 0.1794, 0.3872,
#         0.3646, 0.2363, 0.2495, 0.1292, 0.2070, 0.3101, 0.2811, 0.2811, 0.2013,
#         0.4503, 0.2010, 0.2196, 0.1808, 0.2640, 0.1848, 0.1444, 0.5428, 0.2219,
#         0.4736, 0.2410, 0.1954, 0.4639, 0.2140, 0.2811, 0.2334, 0.2222, 0.1707,
#         0.4841, 0.2824, 0.3918, 0.1863, 0.3509, 0.2883, 0.1876, 0.3613, 0.4231,
#         0.1876, 0.2662, 0.1984, 0.1001, 0.2613, 0.2196, 0.2613, 0.2669, 0.1720,
#         0.1963, 0.1824, 0.2103, 0.1499, 0.3536, 0.2704, 0.3252, 0.1796, 0.1652,
#         0.2640, 0.7000, 0.2140, 0.3146, 0.1405, 0.1608, 0.3377, 0.1607, 0.2151,
#         0.2003, 0.2208, 0.2376])

# %%
# Out:
# <Axes: >
